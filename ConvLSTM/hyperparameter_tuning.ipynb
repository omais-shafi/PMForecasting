  (14000, 10, 0.2863684975757118, 14.669543128723156),
  (14000, 11, 0.27886524059226797, 13.074033181383994),
  (14000, 12, 0.7260196667863181, 19.998251266321702),
  (14000, 13, 0.2122845816545241, 15.40980869379929),
  (14000, 14, 0.31370031387035535, 17.397210504836956),
  (14000, 15, 1.7896654204200066, 13.94975474152262),
  (14000, 16, 6.060484246272439, 19.918112389779182)],
 [(15000, 4, 1.209534847922888, 17.976031982339098),
  (15000, 5, 2.226376816887457, 15.179684986972257),
  (15000, 6, 0.5925981743274289, 15.286950543963755),
  (15000, 7, 0.6717056460188272, 23.651707322672156),
  (15000, 8, 0.5660390255384028, 19.686157568319103),
  (15000, 9, 0.6531835164773669, 18.828241700883144),
  (15000, 10, 0.2341179152998771, 15.827529700213258),
  (15000, 11, 0.7474624302841443, 21.779896501167368),
  (15000, 12, 0.36207291420555276, 14.961489260386877),
  (15000, 13, 3.4710799631432674, 15.549161656586385),
  (15000, 14, 0.5094113342806492, 14.948483311704653),
  (15000, 15, 0.11357326113558738, 12.693228194284837),
  (15000, 16, 0.1794416258851484, 15.11649505843079)],
 [(16000, 4, 1.4892697393221186, 15.016767666752608),
  (16000, 5, 2.0224841607868145, 16.666453143977293),
  (16000, 6, 1.9780237880082518, 18.85116830944065),
  (16000, 7, 1.502133362351827, 17.02687013636461),
  (16000, 8, 0.340740358434559, 16.2112622331933),
  (16000, 9, 0.4444559626858331, 19.778103305456977),
  (16000, 10, 1.519588126169855, 12.677120980818346),
  (16000, 11, 0.36732147694461614, 14.003276986385075),
  (16000, 12, 0.11129810530831234, 17.83681950704646),
  (16000, 13, 1.0645088951129804, 19.840580147905673),
  (16000, 14, 1.5346502581602155, 21.533625367883946),
  (16000, 15, 0.21547016375702369, 17.3612497932829),
  (16000, 16, 5.919751755432593, 20.01973894709333)]]

# %%
import matplotlib.pyplot as plt

hidden_fixed = [[] for _ in range(4,17)]

for j in range(4,17):
    count = 0
    for i in range(10000,17000,1000):
        hidden_fixed[j-4].append(l[count][j-4][3])
        count+=1
        
epochs_fixed = [[] for _ in range(10000,17000,1000)]

count = 0
for j in range(10000,17000,1000):
    for i in range(4,17):
        epochs_fixed[count].append(l[count][i-4][3])
    count+=1

# %%
plt.title("Test RMSE vs Epochs")
plt.xlabel("Epochs")
plt.ylabel("Test RMSE")
for i in range(4,8):
    plt.plot(range(10000,17000,1000),hidden_fixed[i-4],label=f"Hidden Channels {i}")
plt.legend(bbox_to_anchor=(1.5,1), loc="upper right")
plt.show()

# %%
plt.title("Test RMSE vs Epochs")
plt.xlabel("Epochs")
plt.ylabel("Test RMSE")
for i in range(8,12):
    plt.plot(range(10000,17000,1000),hidden_fixed[i-4],label=f"Hidden Channels {i}")
plt.legend(bbox_to_anchor=(1.5,1), loc="upper right")
plt.show()

# %%
plt.title("Test RMSE vs Epochs")
plt.xlabel("Epochs")
plt.ylabel("Test RMSE")
for i in range(12,17):
    plt.plot(range(10000,17000,1000),hidden_fixed[i-4],label=f"Hidden Channels {i}")
plt.legend(bbox_to_anchor=(1.5,1), loc="upper right")
plt.show()

# %%
plt.title("Test RMSE vs Hidden Channels")
plt.xlabel("Hidden Channels")
plt.ylabel("Test RMSE")
for i in range(0,3):
    plt.plot(range(4,17),epochs_fixed[i],label=f"Epochs {i*1000+10000}")
plt.legend(bbox_to_anchor=(1.5,1), loc="upper right")
plt.show()

# %%
plt.title("Test RMSE vs Hidden Channels")
plt.xlabel("Hidden Channels")
plt.ylabel("Test RMSE")
for i in range(3,7):
    plt.plot(range(4,17),epochs_fixed[i],label=f"Epochs {i*1000+10000}")
plt.legend(bbox_to_anchor=(1.5,1), loc="upper right")
plt.show()
